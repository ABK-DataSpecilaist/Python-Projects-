# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv(r'C:\Users\maakh\Downloads\PythonJubyterfiles\heart-attack-prediction-main\heartattackpredictiondataset.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (8763, 26)

# %%
df.head(5)
# Out:
#   Patient ID     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812    Male          208         158/88          72         0
# 1    CZE1114    Male          389         165/93          98         1
# 2    BNI9906  Female          324         174/99          72         1
# 3    JLN3497    Male          383        163/100          73         1
# 4    GFO8847    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  Alcohol Consumption  ...        BMI  \
# 0               0        1        0                    0  ...  31.251233
# 1               1        1        1                    1  ...  27.194973
# 2               0        0        0                    0  ...  28.176571
# 3               1        1        0                    1  ...  36.464704
# 4               1        1        1                    0  ...  21.809144
#
#   Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# ...

# %%
df.info()
# Summary of csv file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Sex                              8763 non-null   object
#  2   Cholesterol                      8763 non-null   int64
#  3   Blood Pressure                   8763 non-null   object
#  4   Heart Rate                       8763 non-null   int64
#  5   Diabetes                         8763 non-null   int64
#  6   Family History                   8763 non-null   int64
#  7   Smoking                          8763 non-null   int64
#  8   Obesity                          8763 non-null   int64
#  9   Alcohol Consumption              8763 non-null   int64
#  10  Exercise Hours Per Week          8763 non-null   float64
#  11  Diet                             8763 non-null   object
# ...

# %%
df.to_csv('HRP.csv', index=False)

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
ax = sns.countplot(data = df, x = 'Age', hue = 'Sex')

for bars in ax.containers:
    sns.set(rc={'figure.figsize':(30,5)})
    ax.bar_label(bars)

# %%
# Counting individuals by sex
sex_counts = df['Sex'].value_counts()

# %%
# Plotting pie chart
plt.figure(figsize=(4, 4))
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', startangle=100)
plt.title('Sex Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df.to_csv('HRP.csv', index=False)

# %%
ax = sns.countplot(x = 'Income Group', data = df,hue = 'Income Group')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Sex')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Gender and it's count
ax = sns.countplot(x = 'Sex',data = df,hue = 'Sex')
sns.set(rc={'figure.figsize':(30,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Define the age groups
age_bins = [20, 30, 40, 50, 60, 70, 80, 90, 100]
age_labels = ['0-19','20-29', '30-39', '40-49', '50-59','60-69', '70-79', '80+']

# Adding a new column 'Age Group' to the DataFrame
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# %%
df.drop(['Age', 'Income'], axis=1, inplace=True)

# %%
df.to_csv('heartattackpredictiondataset.csv', index=False)

# %%
pd.isnull(df).sum()
# Out:
# Patient ID                         0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Heart Attack Risk                  0
# Income Group                       0
# ...

# %%
df['Age Group'].fillna('40-49', inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Patient ID                            0
# Sex                                   0
# Cholesterol                           0
# Blood Pressure                        0
# Heart Rate                            0
# Diabetes                              0
# Family History                        0
# Smoking                               0
# Obesity                               0
# Alcohol Consumption                   0
# Exercise Hours Per Week               0
# Diet                                  0
# Previous Heart Problems               0
# Medication Use                        0
# Stress Level                          0
# Sedentary Hours Per Day               0
# BMI                                   0
# Triglycerides                         0
# Physical Activity Days Per Week       0
# Sleep Hours Per Day                   0
# Country                               0
# Continent                             0
# Hemisphere                            0
# ...

# %%
df['Income Group'].fillna('Medium', inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16000\304732910.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income Group'].fillna('Medium', inplace=True)

# %%
df.to_csv('heartattackpredictiondataset.csv', index=False)

# %%
pd.isnull(df).sum()
# Out:
# Patient ID                         0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Heart Attack Risk                  0
# Income Group                       0
# ...

# %%
df.to_csv('heartattackpredictiondataset.csv', index=False)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Age Group', y='Heart Attack Risk', data=df, estimator=sum, ci=None)
plt.title('Total Heart Attack Risk by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Heart Attack Risk')
plt.show()
# Out:
# C:\Users\maakh\AppData\Local\Temp\ipykernel_15280\2391869889.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Age Group', y='Heart Attack Risk', data=df, estimator=sum, ci=None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Define the correct order of age groups (modify as per your actual age group labels)
age_order = ['0-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80+']

# Convert 'Age Group' to ordered categorical type
df['Age Group'] = pd.Categorical(df['Age Group'], categories=age_order, ordered=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Age Group', y='Heart Attack Risk', data=df, estimator=sum, ci=None,
            order=age_order)
plt.title('Total Heart Attack Risk by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Heart Attack Risk')
plt.xticks(rotation=45)  # Optional: rotate labels if they overlap
plt.tight_layout()
plt.show()
# Out:
# C:\Users\maakh\AppData\Local\Temp\ipykernel_15280\451005974.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Age Group', y='Heart Attack Risk', data=df, estimator=sum, ci=None,

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Plotting bar chart for the count of rows by age group
sns.barplot(x=row_counts.index, y=row_counts.values, color='skyblue', label='Total Rows')

# Plotting bar chart for the sum of heart attack risk by age group
sns.barplot(x='Age Group', y='Heart Attack Risk', data=df, estimator=sum, ci=None, color='salmon', label='Heart Attack Risk')

plt.title('Age Group vs Heart Attack Risk vs Total Rows')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2 plt.figure(figsize=(10, 6))
#       4 # Plotting bar chart for the count of rows by age group
# ----> 5 sns.barplot(x=row_counts.index, y=row_counts.values, color='skyblue', label='Total Rows')
#       7 # Plotting bar chart for the sum of heart attack risk by age group
#       8 sns.barplot(x='Age Group', y='Heart Attack Risk', data=df, estimator=sum, ci=None, color='salmon', label='Heart Attack Risk')
#
# NameError: name 'row_counts' is not defined

# %%
import matplotlib.pyplot as plt

# Data
genders = ['Female', 'Male']
percentages = [36.0, 36.0]

# Plot
plt.figure(figsize=(6, 5))
bars = plt.bar(genders, percentages, color=['#FF69B4', '#1E90FF'])

# Add value labels on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.2f}%', ha='center', va='bottom', fontsize=12)

# Titles and labels
plt.title('Heart Attack Prediction Chart by Gender')
plt.ylabel('Perdiction Percentage')
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Family history Yes', 'Family history No']
female_values = [35.00, 36.00]
male_values = [36.00, 35.00]

# Bar positions
x = np.arange(len(categories))
width = 0.35  # Width of bars

# Plot
fig, ax = plt.subplots(figsize=(8, 6))
bars1 = ax.bar(x - width/2, female_values, width, label='Female', color='#FF69B4')
bars2 = ax.bar(x + width/2, male_values, width, label='Male', color='#1E90FF')

# Add value labels
for bar in bars1 + bars2:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 0.5, f'{yval:.2f}%', ha='center', va='bottom', fontsize=10)

# Labels, title, legend
ax.set_ylabel('Percentage')
ax.set_title('Heart Attack Prediction by Gender and Family History')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, max(max(female_values), max(male_values)) + 10)
ax.legend()

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Data
categories = ['Diet-Average', 'Diet-Healthy', 'Diet-unhealthy']
female_values = [35.30, 35.00, 36.40 ]
male_values = [35.2, 37.00, 35.00]

# Bar positions
x = np.arange(len(categories))
width = 0.35  # Width of bars

# Plot
fig, ax = plt.subplots(figsize=(8, 6))
bars1 = ax.bar(x - width/2, female_values, width, label='Female', color='#FF69B4')
bars2 = ax.bar(x + width/2, male_values, width, label='Male', color='#1E90FF')

# Add value labels
for bar in bars1 + bars2:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 0.5, f'{yval:.2f}%', ha='center', va='bottom', fontsize=10)

# Labels, title, legend
ax.set_ylabel('Percentage')
ax.set_title('Heart Attack Prediction by Gender and Family History')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, max(max(female_values), max(male_values)) + 10)
ax.legend()

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
CountryHRP = df.groupby(['Country', 'Sex'], as_index=False)['Heart Attack Risk'].sum().sort_values(by='Heart Attack Risk', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = CountryHRP, x = 'Country',y= 'Heart Attack Risk', hue='Gender')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 CountryHRP = df.groupby(['Country', 'Sex'], as_index=False)['Heart Attack Risk'].sum().sort_values(by='Heart Attack Risk', ascending=False)
#       3 sns.set(rc={'figure.figsize':(6,5)})
#       4 sns.barplot(data = CountryHRP, x = 'Country',y= 'Heart Attack Risk', hue='Gender')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Step 1: Count total and positive cases
total_counts = df.groupby(['Country', 'Sex']).size().reset_index(name='Total')
positive_counts = df[df['Heart Attack Risk'] == 1].groupby(['Country', 'Sex']).size().reset_index(name='Positive')

# Step 2: Merge and calculate percentage
merged = pd.merge(total_counts, positive_counts, on=['Country', 'Sex'], how='left').fillna(0)
merged['Heart Attack Risk (%)'] = (merged['Positive'] / merged['Total']) * 100

# Step 3: Plot
plt.figure(figsize=(14, 6))
barplot = sns.barplot(data=merged, x='Country', y='Heart Attack Risk (%)', hue='Sex',
                      palette={'Female': '#FF69B4', 'Male': '#1E90FF'})

# Step 4: Add value labels
for container in barplot.containers:
    barplot.bar_label(container, fmt='%.1f%%', label_type='edge', padding=3, fontsize=9)

# Customize
plt.title('Heart Attack Risk Percentage by Country and Sex')
plt.xlabel('Country')
plt.ylabel('Heart Attack Risk (%)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sex')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 7
#       3 import matplotlib.pyplot as plt
#       5 # Assuming df is your DataFrame
#       6 # Step 1: Count total and positive cases
# ----> 7 total_counts = df.groupby(['Country', 'Sex']).size().reset_index(name='Total')
#       8 positive_counts = df[df['Heart Attack Risk'] == 1].groupby(['Country', 'Sex']).size().reset_index(name='Positive')
#      10 # Step 2: Merge and calculate percentage
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
# ...
